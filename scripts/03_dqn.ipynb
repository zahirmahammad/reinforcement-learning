# %%
# For now we install this update of RL-Baselines3 Zoo
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo
# Out:
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo to /tmp/pip-req-build-b9m8n1vj
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo /tmp/pip-req-build-b9m8n1vj
#
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit d42f9159bfa897871ea912a8ef5ccc92ba364948
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting sb3_contrib<3.0,>=2.8.0a0 (from rl_zoo3==2.8.0a1)
#   Downloading sb3_contrib-2.8.0a0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from rl_zoo3==2.8.0a1) (1.2.3)
# Collecting huggingface_sb3<4.0,>=3.0 (from rl_zoo3==2.8.0a1)
#   Downloading huggingface_sb3-3.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: tqdm in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from rl_zoo3==2.8.0a1) (4.67.1)
# Requirement already satisfied: rich in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from rl_zoo3==2.8.0a1) (14.2.0)
# Collecting optuna>=3.0 (from rl_zoo3==2.8.0a1)
#   Downloading optuna-4.7.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pyyaml>=5.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from rl_zoo3==2.8.0a1) (6.0.3)
# Collecting pytablewriter~=1.2 (from rl_zoo3==2.8.0a1)
#   Downloading pytablewriter-1.2.1-py3-none-any.whl.metadata (38 kB)
# Collecting shimmy~=2.0 (from rl_zoo3==2.8.0a1)
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.21.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.8.0a1) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.8.0a1) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.8.0a1) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.8.0a1) (0.0.4)
# Collecting huggingface-hub~=0.8 (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a1)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Collecting wasabi (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a1)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: filelock in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a1) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a1) (2025.12.0)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a1)
#   Downloading hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: packaging>=20.9 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a1) (25.0)
# Requirement already satisfied: requests in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a1) (2.32.5)
# Requirement already satisfied: setuptools>=38.3.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from pytablewriter~=1.2->rl_zoo3==2.8.0a1) (80.9.0)
# Collecting DataProperty<2,>=1.1.0 (from pytablewriter~=1.2->rl_zoo3==2.8.0a1)
#   Downloading DataProperty-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter~=1.2->rl_zoo3==2.8.0a1)
#   Downloading mbstrdecoder-1.1.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter~=1.2->rl_zoo3==2.8.0a1)
#   Downloading pathvalidate-3.3.1-py3-none-any.whl.metadata (12 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter~=1.2->rl_zoo3==2.8.0a1)
#   Downloading tabledata-1.3.4-py3-none-any.whl.metadata (3.7 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter~=1.2->rl_zoo3==2.8.0a1)
#   Downloading tcolorpy-0.1.7-py3-none-any.whl.metadata (6.3 kB)
# Collecting typepy<2,>=1.3.2 (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.8.0a1)
#   Downloading typepy-1.3.4-py3-none-any.whl.metadata (9.2 kB)
# Collecting chardet<6,>=3.0.4 (from mbstrdecoder<2,>=1.0.0->pytablewriter~=1.2->rl_zoo3==2.8.0a1)
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting stable_baselines3<3.0,>=2.8.0a0 (from sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1)
#   Downloading stable_baselines3-2.8.0a2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: torch<3.0,>=2.3 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (2.8.0+cu128)
# Requirement already satisfied: pandas in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (2.1.4)
# Requirement already satisfied: matplotlib in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (3.8.2)
# Requirement already satisfied: sympy>=1.13.3 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (1.14.0)
# Requirement already satisfied: networkx in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (3.6)
# Requirement already satisfied: jinja2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (3.4.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.8.0a1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2018.9 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.8.0a1) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.8.0a1) (1.17.0)
# Collecting alembic>=1.5.0 (from optuna>=3.0->rl_zoo3==2.8.0a1)
#   Downloading alembic-1.18.4-py3-none-any.whl.metadata (7.2 kB)
# Collecting colorlog (from optuna>=3.0->rl_zoo3==2.8.0a1)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Collecting sqlalchemy>=1.4.2 (from optuna>=3.0->rl_zoo3==2.8.0a1)
#   Downloading sqlalchemy-2.0.46-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Collecting Mako (from alembic>=1.5.0->optuna>=3.0->rl_zoo3==2.8.0a1)
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Collecting greenlet>=1 (from sqlalchemy>=1.4.2->optuna>=3.0->rl_zoo3==2.8.0a1)
#   Downloading greenlet-3.3.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from jinja2->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (1.4.9)
# Requirement already satisfied: pillow>=8 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (3.2.5)
# Requirement already satisfied: tzdata>=2022.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from pandas->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a1) (2025.11.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from rich->rl_zoo3==2.8.0a1) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from rich->rl_zoo3==2.8.0a1) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->rl_zoo3==2.8.0a1) (0.1.2)
# Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 20.9 MB/s  0:00:00
# Downloading hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 87.4 MB/s  0:00:00
# Downloading pytablewriter-1.2.1-py3-none-any.whl (91 kB)
# Downloading DataProperty-1.1.0-py3-none-any.whl (27 kB)
# Downloading mbstrdecoder-1.1.4-py3-none-any.whl (7.9 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
# Downloading pathvalidate-3.3.1-py3-none-any.whl (24 kB)
# Downloading sb3_contrib-2.8.0a0-py3-none-any.whl (92 kB)
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Downloading stable_baselines3-2.8.0a2-py3-none-any.whl (187 kB)
# Downloading tabledata-1.3.4-py3-none-any.whl (11 kB)
# Downloading tcolorpy-0.1.7-py3-none-any.whl (8.1 kB)
# Downloading typepy-1.3.4-py3-none-any.whl (31 kB)
# Downloading optuna-4.7.0-py3-none-any.whl (413 kB)
# Downloading alembic-1.18.4-py3-none-any.whl (263 kB)
# Downloading sqlalchemy-2.0.46-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 158.6 MB/s  0:00:00
# Downloading greenlet-3.3.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (609 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 609.9/609.9 kB 62.2 MB/s  0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Building wheels for collected packages: rl_zoo3
#   Building wheel for rl_zoo3 (pyproject.toml) ... done
#   Created wheel for rl_zoo3: filename=rl_zoo3-2.8.0a1-py3-none-any.whl size=78252 sha256=a0001b7b6977d30fff700c91c15111f33d01de0cec7e89f3145289a6a50dfc33
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c3m1igh_/wheels/cd/09/5b/8130538724a187021e02afe53ce7a1269c516a78a487a1ba15
# Successfully built rl_zoo3
# Installing collected packages: wasabi, tcolorpy, pathvalidate, Mako, hf-xet, greenlet, colorlog, chardet, sqlalchemy, shimmy, mbstrdecoder, huggingface-hub, typepy, huggingface_sb3, alembic, stable_baselines3, optuna, sb3_contrib, DataProperty, tabledata, pytablewriter, rl_zoo3
#   Attempting uninstall: stable_baselines3m╺━━━━━━━━━━━━━━ 14/22 [alembic]ace-hub]
#     Found existing installation: stable_baselines3 2.7.1━━━━━━ 14/22 [alembic]
#     Uninstalling stable_baselines3-2.7.1:0m━━━━━━━━━━━━━━ 14/22 [alembic]
#       Successfully uninstalled stable_baselines3-2.7.1━━━━━━━━ 14/22 [alembic]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22/22 [rl_zoo3]0/22 [pytablewriter]es3]
# Successfully installed DataProperty-1.1.0 Mako-1.3.10 alembic-1.18.4 chardet-5.2.0 colorlog-6.10.1 greenlet-3.3.1 hf-xet-1.2.0 huggingface-hub-0.36.2 huggingface_sb3-3.0 mbstrdecoder-1.1.4 optuna-4.7.0 pathvalidate-3.3.1 pytablewriter-1.2.1 rl_zoo3-2.8.0a1 sb3_contrib-2.8.0a0 shimmy-2.0.0 sqlalchemy-2.0.46 stable_baselines3-2.8.0a2 tabledata-1.3.4 tcolorpy-0.1.7 typepy-1.3.4 wasabi-1.1.3

# %%
# !pip install "gymnasium[all]"
# !pip install "gymnasium[accept-rom-license]"
# Out:
# Requirement already satisfied: gymnasium[all] in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium[all]) (2.3.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium[all]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium[all]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium[all]) (0.0.4)
# Requirement already satisfied: ale_py>=0.9 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium[all]) (0.11.2)
# Requirement already satisfied: box2d==2.3.10 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium[all]) (2.3.10)
# Requirement already satisfied: pygame>=2.1.3 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium[all]) (2.6.1)
# Requirement already satisfied: swig==4.* in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium[all]) (4.4.1)
# Requirement already satisfied: mujoco>=2.1.5 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium[all]) (3.5.0)
# Requirement already satisfied: imageio>=2.14.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium[all]) (2.37.2)
# Requirement already satisfied: packaging>=23.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium[all]) (25.0)
# Requirement already satisfied: jax>=0.4.16 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium[all]) (0.9.0.1)
# Requirement already satisfied: jaxlib>=0.4.16 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium[all]) (0.9.0.1)
# Requirement already satisfied: flax>=0.5.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium[all]) (0.12.4)
# Requirement already satisfied: array-api-compat>=1.11.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium[all]) (1.13.0)
# Requirement already satisfied: torch>=1.13.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium[all]) (2.8.0+cu128)
# Requirement already satisfied: opencv-python>=3.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium[all]) (4.13.0.92)
# Requirement already satisfied: matplotlib>=3.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium[all]) (3.10.8)
# Requirement already satisfied: moviepy>=1.0.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium[all]) (2.2.1)
# Requirement already satisfied: msgpack in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from flax>=0.5.0->gymnasium[all]) (1.1.2)
# Requirement already satisfied: optax==0.2.6 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from flax>=0.5.0->gymnasium[all]) (0.2.6)
# Requirement already satisfied: orbax-checkpoint in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from flax>=0.5.0->gymnasium[all]) (0.11.33)
# Requirement already satisfied: tensorstore in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from flax>=0.5.0->gymnasium[all]) (0.1.81)
# Requirement already satisfied: rich>=11.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from flax>=0.5.0->gymnasium[all]) (14.2.0)
# Requirement already satisfied: PyYAML>=5.4.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from flax>=0.5.0->gymnasium[all]) (6.0.3)
# Requirement already satisfied: treescope>=0.1.7 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from flax>=0.5.0->gymnasium[all]) (0.1.10)
# Requirement already satisfied: orbax-export>=0.0.8 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from flax>=0.5.0->gymnasium[all]) (0.0.8)
# Requirement already satisfied: absl-py>=0.7.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from optax==0.2.6->flax>=0.5.0->gymnasium[all]) (2.3.1)
# Requirement already satisfied: chex>=0.1.87 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from optax==0.2.6->flax>=0.5.0->gymnasium[all]) (0.1.91)
# Requirement already satisfied: toolz>=1.0.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from chex>=0.1.87->optax==0.2.6->flax>=0.5.0->gymnasium[all]) (1.1.0)
# Requirement already satisfied: pillow>=8.3.2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from imageio>=2.14.1->gymnasium[all]) (11.3.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from jax>=0.4.16->gymnasium[all]) (0.5.4)
# Requirement already satisfied: opt_einsum in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from jax>=0.4.16->gymnasium[all]) (3.4.0)
# Requirement already satisfied: scipy>=1.13 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from jax>=0.4.16->gymnasium[all]) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib>=3.0->gymnasium[all]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib>=3.0->gymnasium[all]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib>=3.0->gymnasium[all]) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib>=3.0->gymnasium[all]) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib>=3.0->gymnasium[all]) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from matplotlib>=3.0->gymnasium[all]) (2.9.0.post0)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from moviepy>=1.0.0->gymnasium[all]) (5.2.1)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from moviepy>=1.0.0->gymnasium[all]) (0.6.0)
# Requirement already satisfied: proglog<=1.0.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from moviepy>=1.0.0->gymnasium[all]) (0.1.12)
# Requirement already satisfied: python-dotenv>=0.10 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from moviepy>=1.0.0->gymnasium[all]) (1.2.1)
# Requirement already satisfied: tqdm in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from proglog<=1.0.0->moviepy>=1.0.0->gymnasium[all]) (4.67.1)
# Requirement already satisfied: etils[epath] in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from mujoco>=2.1.5->gymnasium[all]) (1.13.0)
# Requirement already satisfied: glfw in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from mujoco>=2.1.5->gymnasium[all]) (2.10.0)
# Requirement already satisfied: pyopengl in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from mujoco>=2.1.5->gymnasium[all]) (3.1.10)
# Requirement already satisfied: dataclasses-json in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from orbax-export>=0.0.8->flax>=0.5.0->gymnasium[all]) (0.6.7)
# Requirement already satisfied: jaxtyping in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from orbax-export>=0.0.8->flax>=0.5.0->gymnasium[all]) (0.3.9)
# Requirement already satisfied: protobuf in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from orbax-export>=0.0.8->flax>=0.5.0->gymnasium[all]) (4.23.4)
# Requirement already satisfied: aiofiles in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (25.1.0)
# Requirement already satisfied: humanize in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (4.15.0)
# Requirement already satisfied: simplejson>=3.16.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (3.20.2)
# Requirement already satisfied: psutil in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (7.1.3)
# Requirement already satisfied: uvloop in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (0.22.1)
# Requirement already satisfied: six>=1.5 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->gymnasium[all]) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from rich>=11.1->flax>=0.5.0->gymnasium[all]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from rich>=11.1->flax>=0.5.0->gymnasium[all]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.5.0->gymnasium[all]) (0.1.2)
# Requirement already satisfied: filelock in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (3.20.0)
# Requirement already satisfied: setuptools in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (1.14.0)
# Requirement already satisfied: networkx in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (3.6)
# Requirement already satisfied: jinja2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (3.1.6)
# Requirement already satisfied: fsspec in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (2025.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.13.0->gymnasium[all]) (1.3.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from dataclasses-json->orbax-export>=0.0.8->flax>=0.5.0->gymnasium[all]) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from dataclasses-json->orbax-export>=0.0.8->flax>=0.5.0->gymnasium[all]) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->orbax-export>=0.0.8->flax>=0.5.0->gymnasium[all]) (1.1.0)
# Requirement already satisfied: importlib_resources in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (6.5.2)
# Requirement already satisfied: zipp in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (3.23.0)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from jaxtyping->orbax-export>=0.0.8->flax>=0.5.0->gymnasium[all]) (0.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from jinja2->torch>=1.13.0->gymnasium[all]) (3.0.3)
# Requirement already satisfied: gymnasium[accept-rom-license] in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (1.2.3)
# WARNING: gymnasium 1.2.3 does not provide the extra 'accept-rom-license'
# Requirement already satisfied: numpy>=1.21.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium[accept-rom-license]) (2.3.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium[accept-rom-license]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium[accept-rom-license]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from gymnasium[accept-rom-license]) (0.0.4)

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml
# Out:
# ========== SpaceInvadersNoFrameskip-v4 ==========
# Seed: 2192129728
# Loading hyperparameters from: dqn.yml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 32),
#              ('buffer_size', 100000),
#              ('env_wrapper',
#               ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
#              ('exploration_final_eps', 0.01),
#              ('exploration_fraction', 0.1),
#              ('frame_stack', 4),
#              ('gradient_steps', 1),
#              ('learning_rate', 0.0001),
#              ('learning_starts', 100000),
#              ('n_timesteps', 10000000.0),
#              ('optimize_memory_usage', False),
#              ('policy', 'CnnPolicy'),
#              ('target_update_interval', 1000),
#              ('train_freq', 4)])
# Using 1 environments
# Creating test environment
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Using cpu device
# Log path: logs//dqn/SpaceInvadersNoFrameskip-v4_2
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.67e+03 |
# |    ep_rew_mean      | 180      |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 858      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 993      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.31e+03 |
# |    ep_rew_mean      | 320      |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 843      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1623     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.51e+03 |
# |    ep_rew_mean      | 238      |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 864      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2469     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.25e+03 |
# |    ep_rew_mean      | 208      |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 880      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2984     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 191      |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 892      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.25e+03 |
# |    ep_rew_mean      | 192      |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 906      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4409     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.45e+03 |
# |    ep_rew_mean      | 203      |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 925      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5542     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.41e+03 |
# |    ep_rew_mean      | 215      |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 917      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6403     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.3e+03  |
# |    ep_rew_mean      | 193      |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 916      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 6760     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.41e+03 |
# |    ep_rew_mean      | 200      |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 919      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 8052     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.45e+03 |
# |    ep_rew_mean      | 218      |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 923      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 8767     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.37e+03 |
# |    ep_rew_mean      | 200      |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 925      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 9283     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.34e+03 |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 926      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 9890     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.32e+03 |
# |    ep_rew_mean      | 194      |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 925      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 10645    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.35e+03 |
# |    ep_rew_mean      | 202      |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 927      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 11536    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.3e+03  |
# |    ep_rew_mean      | 195      |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 928      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 12060    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.37e+03 |
# |    ep_rew_mean      | 202      |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 930      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 13367    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.42e+03 |
# |    ep_rew_mean      | 208      |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 932      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 14238    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.38e+03 |
# |    ep_rew_mean      | 204      |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 933      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 14753    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.35e+03 |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 934      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 15190    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.29e+03 |
# |    ep_rew_mean      | 191      |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 928      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 15698    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.26e+03 |
# |    ep_rew_mean      | 185      |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 929      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 16195    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.24e+03 |
# |    ep_rew_mean      | 180      |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 930      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 16843    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 931      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 17375    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 171      |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 929      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 17891    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 175      |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 931      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 18755    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 172      |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 931      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 19123    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 171      |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 930      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 19987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 172      |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 930      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 20598    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 930      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 21344    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 175      |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 932      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 22020    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 172      |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 932      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 22355    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 170      |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 932      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 23040    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 171      |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 933      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 23925    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 170      |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 933      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 24621    |
# ----------------------------------
# Eval num_timesteps=25000, episode_reward=180.00 +/- 169.26
# Episode length: 2077.40 +/- 767.53
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.08e+03 |
# |    mean_reward      | 180      |
# | rollout/            |          |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    total_timesteps  | 25000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 171      |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 845      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 25156    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 847      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 25669    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 850      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 26426    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 848      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 27085    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 170      |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 853      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 28046    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 170      |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 855      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 28603    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 858      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 29372    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 859      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 29822    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 860      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 30242    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 861      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 30699    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 862      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 31424    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 863      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 32131    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 865      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 32952    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 867      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 33533    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 868      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 33911    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 869      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 34581    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 871      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 35118    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 873      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 35766    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 872      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 36143    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 872      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 36679    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 875      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 37606    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 876      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 38096    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 877      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 38555    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 878      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 39029    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 880      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 39848    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 881      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 40454    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.959    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 880      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 41051    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.959    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 882      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 41779    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 883      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 42418    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 884      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 42962    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 885      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 43454    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 887      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 44566    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 888      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 45210    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 888      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 45612    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 887      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 46186    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 889      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 46893    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.953    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 890      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 47602    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 891      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 48232    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 892      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 48827    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 893      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 49580    |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=147.00 +/- 81.83
# Episode length: 1987.40 +/- 565.31
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.99e+03 |
# |    mean_reward      | 147      |
# | rollout/            |          |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    total_timesteps  | 50000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 854      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 50185    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 855      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 50760    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 856      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 51397    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 858      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 52135    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 858      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 53000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 859      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 53600    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 860      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 54201    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 861      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 54750    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 862      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 55263    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 863      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 55695    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 864      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 56338    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 865      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 57116    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 865      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 57787    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 865      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 58233    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 866      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 58884    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 867      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 59600    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 868      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 60041    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.9e+03  |
# |    ep_rew_mean      | 128      |
# |    exploration_rate | 0.94     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 869      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 60589    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.91e+03 |
# |    ep_rew_mean      | 129      |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 870      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 61360    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.91e+03 |
# |    ep_rew_mean      | 129      |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 871      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 62195    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 871      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 63099    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 872      |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 63729    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 873      |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 64073    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 874      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 64908    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 875      |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 65748    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 876      |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 66315    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 876      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 67193    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 877      |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 68128    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 878      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 68620    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 878      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 69206    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 879      |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 70124    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 880      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 70614    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 881      |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 71819    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 881      |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 72693    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 882      |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 73081    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 883      |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 73723    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 883      |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 74138    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 883      |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 74634    |
# ----------------------------------
# Eval num_timesteps=75000, episode_reward=179.00 +/- 80.15
# Episode length: 2130.60 +/- 626.18
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.13e+03 |
# |    mean_reward      | 179      |
# | rollout/            |          |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    total_timesteps  | 75000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 855      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 75120    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.925    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 856      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 75803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 857      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 76526    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 858      |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 77491    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 859      |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 78130    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.922    |
# ...
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00246  |
# |    n_updates        | 11515    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 255      |
# |    time_elapsed     | 574      |
# |    total_timesteps  | 146858   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00238  |
# |    n_updates        | 11714    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.854    |
# | time/               |          |
# |    episodes         | 888      |
# |    fps              | 254      |
# |    time_elapsed     | 580      |
# |    total_timesteps  | 147579   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0287   |
# |    n_updates        | 11894    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 892      |
# |    fps              | 252      |
# |    time_elapsed     | 586      |
# |    total_timesteps  | 148111   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0193   |
# |    n_updates        | 12027    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 896      |
# |    fps              | 251      |
# |    time_elapsed     | 590      |
# |    total_timesteps  | 148600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00587  |
# |    n_updates        | 12149    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.852    |
# | time/               |          |
# |    episodes         | 900      |
# |    fps              | 248      |
# |    time_elapsed     | 602      |
# |    total_timesteps  | 149814   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00516  |
# |    n_updates        | 12453    |
# ----------------------------------
# Eval num_timesteps=150000, episode_reward=237.00 +/- 147.43
# Episode length: 2462.60 +/- 527.78
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.46e+03 |
# |    mean_reward      | 237      |
# | rollout/            |          |
# |    exploration_rate | 0.852    |
# | time/               |          |
# |    total_timesteps  | 150000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000845 |
# |    n_updates        | 12499    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 904      |
# |    fps              | 245      |
# |    time_elapsed     | 614      |
# |    total_timesteps  | 150714   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0544   |
# |    n_updates        | 12678    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 908      |
# |    fps              | 243      |
# |    time_elapsed     | 621      |
# |    total_timesteps  | 151462   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00344  |
# |    n_updates        | 12865    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 912      |
# |    fps              | 242      |
# |    time_elapsed     | 628      |
# |    total_timesteps  | 152153   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00891  |
# |    n_updates        | 13038    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 916      |
# |    fps              | 241      |
# |    time_elapsed     | 634      |
# |    total_timesteps  | 152806   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.039    |
# |    n_updates        | 13201    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 920      |
# |    fps              | 239      |
# |    time_elapsed     | 640      |
# |    total_timesteps  | 153545   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00619  |
# |    n_updates        | 13386    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 924      |
# |    fps              | 238      |
# |    time_elapsed     | 647      |
# |    total_timesteps  | 154247   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00667  |
# |    n_updates        | 13561    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 928      |
# |    fps              | 237      |
# |    time_elapsed     | 652      |
# |    total_timesteps  | 154756   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00193  |
# |    n_updates        | 13688    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.846    |
# | time/               |          |
# |    episodes         | 932      |
# |    fps              | 236      |
# |    time_elapsed     | 656      |
# |    total_timesteps  | 155208   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00381  |
# |    n_updates        | 13801    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.846    |
# | time/               |          |
# |    episodes         | 936      |
# |    fps              | 235      |
# |    time_elapsed     | 662      |
# |    total_timesteps  | 155881   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00253  |
# |    n_updates        | 13970    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 940      |
# |    fps              | 233      |
# |    time_elapsed     | 672      |
# |    total_timesteps  | 156943   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.033    |
# |    n_updates        | 14235    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 944      |
# |    fps              | 232      |
# |    time_elapsed     | 677      |
# |    total_timesteps  | 157421   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00391  |
# |    n_updates        | 14355    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 948      |
# |    fps              | 231      |
# |    time_elapsed     | 683      |
# |    total_timesteps  | 158102   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00573  |
# |    n_updates        | 14525    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 952      |
# |    fps              | 230      |
# |    time_elapsed     | 690      |
# |    total_timesteps  | 158783   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0089   |
# |    n_updates        | 14695    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 956      |
# |    fps              | 228      |
# |    time_elapsed     | 698      |
# |    total_timesteps  | 159625   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0312   |
# |    n_updates        | 14906    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.841    |
# | time/               |          |
# |    episodes         | 960      |
# |    fps              | 227      |
# |    time_elapsed     | 703      |
# |    total_timesteps  | 160178   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0045   |
# |    n_updates        | 15044    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.841    |
# | time/               |          |
# |    episodes         | 964      |
# |    fps              | 226      |
# |    time_elapsed     | 710      |
# |    total_timesteps  | 160963   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00207  |
# |    n_updates        | 15240    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 968      |
# |    fps              | 225      |
# |    time_elapsed     | 715      |
# |    total_timesteps  | 161487   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0181   |
# |    n_updates        | 15371    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 972      |
# |    fps              | 224      |
# |    time_elapsed     | 720      |
# |    total_timesteps  | 162012   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0185   |
# |    n_updates        | 15502    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.839    |
# | time/               |          |
# |    episodes         | 976      |
# |    fps              | 223      |
# |    time_elapsed     | 728      |
# |    total_timesteps  | 162843   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0111   |
# |    n_updates        | 15710    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 980      |
# |    fps              | 222      |
# |    time_elapsed     | 732      |
# |    total_timesteps  | 163205   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.027    |
# |    n_updates        | 15801    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 984      |
# |    fps              | 221      |
# |    time_elapsed     | 741      |
# |    total_timesteps  | 164173   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00637  |
# |    n_updates        | 16043    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 988      |
# |    fps              | 220      |
# |    time_elapsed     | 748      |
# |    total_timesteps  | 164956   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0333   |
# |    n_updates        | 16238    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 992      |
# |    fps              | 219      |
# |    time_elapsed     | 752      |
# |    total_timesteps  | 165419   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00372  |
# |    n_updates        | 16354    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 996      |
# |    fps              | 218      |
# |    time_elapsed     | 757      |
# |    total_timesteps  | 165882   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00399  |
# |    n_updates        | 16470    |
# ----------------------------------
